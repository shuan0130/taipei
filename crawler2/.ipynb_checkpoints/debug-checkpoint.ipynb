# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import csv
import threading
import time
import re
from math import cos
import numpy as np
from trans_state import state_code_compute
from lat_lon import geoc

# %%
ele_r = requests.get("https://zh.wikipedia.org/wiki/%E8%87%BA%E5%8C%97%E5%B8%82%E5%9C%8B%E6%B0%91%E5%B0%8F%E5%AD%B8%E5%88%97%E8%A1%A8")
ele_tb = pd.read_html(ele_r.text)
for eledf in ele_tb :
    eledf = pd.concat(ele_tb[0:12],ignore_index=True)
eledf = eledf.drop([2],axis=1)
eledf.columns = ['校名','地址']
eledf = eledf.drop_duplicates()
eledf = eledf.drop([0])
eledf = geoc(eledf,3)
# new_col = eledf.apply(state_code_compute,axis=1)
# eledf['state_code'] = new_col
# Out:
# the current key number is 4
# C:\Users\Big data\Education\edu_crawler\taipei\crawler2\lat_lon.py:49: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   x['lat'][i] = lat
# C:\Users\Big data\Education\edu_crawler\taipei\crawler2\lat_lon.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   x['long'][i] = long
# 1
# 緯度為: 25.0500356
# 經度為: 121.5649528
# 2
# 緯度為: 25.0523018
# 經度為: 121.5634876
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     379             try:  # Python 2.7, use buffering of HTTP responses
# --> 380                 httplib_response = conn.getresponse(buffering=True)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-d612d42af914> in <module>()
#       7 eledf = eledf.drop_duplicates()
#       8 eledf = eledf.drop([0])
# ----> 9 eledf = geoc(eledf,3)
#      10 new_col = eledf.apply(state_code_compute,axis=1)
#      11 # eledf['state_code'] = new_col
#
# ~\Education\edu_crawler\taipei\crawler2\lat_lon.py in geoc(x, key_num1)
#      32                 addr = x.iloc[i][1]
#      33                 url = 'https://maps.googleapis.com/maps/api/geocode/xml?address=' + addr + '&key=' + key_list[int(key_num1)]
# ---> 34                 r = requests.get(url)
#      35                 content = r.content
#      36                 bsobj = BeautifulSoup(content, 'html.parser')
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      70
#      71     kwargs.setdefault('allow_redirects', True)
# ---> 72     return request('get', url, params=params, **kwargs)
#      73
#      74
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56     # cases, and look like a memory leak in others.
#      57     with sessions.Session() as session:
# ---> 58         return session.request(method=method, url=url, **kwargs)
#      59
#      60
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     506         }
#     507         send_kwargs.update(settings)
# --> 508         resp = self.send(prep, **send_kwargs)
#     509
#     510         return resp
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     616
#     617         # Send the request
# --> 618         r = adapter.send(request, **kwargs)
#     619
#     620         # Total elapsed time of the request (approximately)
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381             except TypeError:  # Python 2.6 and older, Python 3
#     382                 try:
# --> 383                     httplib_response = conn.getresponse()
#     384                 except Exception as e:
#     385                     # Remove the TypeError from the exception chain in Python 3;
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\http\client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\http\client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\http\client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1007                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1008                   self.__class__)
# -> 1009             return self.read(nbytes, buffer)
#    1010         else:
#    1011             return socket.recv_into(self, buffer, nbytes, flags)
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\ssl.py in read(self, len, buffer)
#     869             raise ValueError("Read on closed or unwrapped SSL socket.")
#     870         try:
# --> 871             return self._sslobj.read(len, buffer)
#     872         except SSLError as x:
#     873             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# c:\users\big data\appdata\local\programs\python\python36-32\lib\ssl.py in read(self, len, buffer)
#     629         """
#     630         if buffer is not None:
# --> 631             v = self._sslobj.read(len, buffer)
#     632         else:
#     633             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
out_path = "C:/Users/Big data/Education/elemen.csv"
eledf.to_csv(out_path,index = False,encoding = 'utf-8-sig')

# %%
highdf
# Out:
#         校名                   地址        lat        long
# 0     建國中學         臺北市中正區南海路56號  25.030689  121.512811
# 1     北一女中     臺北市中正區重慶南路一段165號  25.038561  121.513103
# 2     成功高中       臺北市中正區濟南路一段71號  25.042334  121.523687
# 3     南華高中       臺北市中正區汀州路三段58號  25.015618  121.531192
# 4     強恕高中      臺北市中正區汀州路二段143號  25.025016  121.519941
# 5     開南商工        臺北市中正區濟南路一段6號  25.042420  121.521821
# 6     成淵高中      臺北市大同區承德路二段235號  25.060974  121.519137
# 7     志仁高中     臺北市大同區南京西路64巷17號  25.052162  121.518781
# 8     明倫高中      臺北市大同區承德路三段336號  25.076246  121.519339
# 9     靜修女中         臺北市大同區寧夏路59號  25.057931  121.515487
# 10    啟聰學校     臺北市大同區重慶北路三段320號  25.075351  121.513553
# 11    稻江高商    臺北市大同區民權西路225巷24號  25.064349  121.511976
# 12    中山女中     臺北市中山區長安東路二段141號  25.048512  121.537212
# 66    再興中學        臺北市文山區興隆路四段2號  24.990414  121.559161
# 67    大誠高中      臺北市文山區秀明路二段175號  24.991053  121.578524
# 68    東山高中       臺北市文山區老泉街26巷3號  24.972689  121.561698
# 69    景文高中        臺北市文山區保儀路127號  24.985480  121.567384
# 70    滬江高中     臺北市文山區羅斯福路六段336號  24.989488  121.538885
# 71    文山特教      臺北市文山區秀明路一段169號  24.991540  121.567807
#
# [72 rows x 4 columns]

# %%
if 'lat' not in highdf.columns:
    highdf['lat'] = pd.Series(np.zeros(len(highdf)), index=highdf.index)
    highdf['long'] = pd.Series(np.zeros(len(highdf)), index=highdf.index)

# %%
highdf
# Out:
#         校名                   地址  lat  long
# 1     學校名稱                 學校地址  0.0   0.0
# 2     建國中學         臺北市中正區南海路56號  0.0   0.0
# 3     北一女中     臺北市中正區重慶南路一段165號  0.0   0.0
# 4     成功高中       臺北市中正區濟南路一段71號  0.0   0.0
# 5     南華高中       臺北市中正區汀州路三段58號  0.0   0.0
# 6     強恕高中      臺北市中正區汀州路二段143號  0.0   0.0
# 7     開南商工        臺北市中正區濟南路一段6號  0.0   0.0
# 9     成淵高中      臺北市大同區承德路二段235號  0.0   0.0
# 10    志仁高中     臺北市大同區南京西路64巷17號  0.0   0.0
# 11    明倫高中      臺北市大同區承德路三段336號  0.0   0.0
# 12    靜修女中         臺北市大同區寧夏路59號  0.0   0.0
# 13    啟聰學校     臺北市大同區重慶北路三段320號  0.0   0.0
# 14    稻江高商    臺北市大同區民權西路225巷24號  0.0   0.0
# 16    中山女中     臺北市中山區長安東路二段141號  0.0   0.0
# 17    大直高中        臺北市中山區北安路420號  0.0   0.0
# 18    中興高中         臺北市中山區朱崙街42號  0.0   0.0
# 19  市立大同高中        臺北市中山區長春路167號  0.0   0.0
# 20  私立大同高中      臺北市中山區中山北路三段40號  0.0   0.0
# 21    稻江護家      臺北市中山區新生北路三段55號  0.0   0.0
# 23    中崙高中      臺北市松山區八德路四段101號  0.0   0.0
# 24    西松高中      臺北市松山區健康路325巷7號  0.0   0.0
# 25    育達家商         臺北市松山區寧安街12號  0.0   0.0
# 27    師大附中      臺北市大安區信義路三段143號  0.0   0.0
# 28    復興實中     臺北市大安區敦化南路一段262號  0.0   0.0
# 29    大安高工   臺北市大安區龍圖里復興南路二段52號  0.0   0.0
# 30    和平高中        臺北市大安區臥龍街100號  0.0   0.0
# 31    延平中學     臺北市大安區建國南路一段275號  0.0   0.0
# 32    金甌女中       臺北市大安區杭州南路二段1號  0.0   0.0
# 33    開平餐飲  臺北市大安區復興南路二段148巷24號  0.0   0.0
# 34    東方工商    臺北市大安區信義路四段186巷8號  0.0   0.0
# ..     ...                  ...  ...   ...
# 51    衛理女中      臺北市士林區至善路二段321號  0.0   0.0
# 52    士林高商        臺北市士林區士商路150號  0.0   0.0
# 53    華岡藝校       臺北市士林區建業路73巷8號  0.0   0.0
# 54    啟明學校    臺北市士林區忠誠路二段207巷1號  0.0   0.0
# 56    中正高中        臺北市北投區文林北路77號  0.0   0.0
# 57    薇閣高中         臺北市北投區珠海路50號  0.0   0.0
# 58    復興高中        臺北市北投區復興四路70號  0.0   0.0
# 59    十信高中       臺北市北投區北投路二段55號  0.0   0.0
# 60    奎山實中        臺北市北投區明德路200號  0.0   0.0
# 61    惇敘工商        臺北市北投區泉源路221號  0.0   0.0
# 63    內湖高中        臺北市內湖區文德路218號  0.0   0.0
# 64    麗山高中      臺北市內湖區環山路二段100號  0.0   0.0
# 65    文德女中       臺北市內湖區成功路三段70號  0.0   0.0
# 66    方濟高中       臺北市內湖區成功路三段61號  0.0   0.0
# 67    達人女中      臺北市內湖區內湖路二段314號  0.0   0.0
# 68    南湖高中      臺北市內湖區康寧路三段220號  0.0   0.0
# 69    內湖高工      臺北市內湖區內湖路一段520號  0.0   0.0
# 71    南港高中         臺北市南港區向陽路21號  0.0   0.0
# 72    南港高工         臺北市南港區興中路29號  0.0   0.0
# 73    育成高中        臺北市南港區重陽路366號  0.0   0.0
# 75    景美女中      臺北市文山區木新路三段312號  0.0   0.0
# 76    政大附中       臺北市文山區政大一街353號  0.0   0.0
# 77    木柵高工       臺北市文山區木柵路四段77號  0.0   0.0
# 78    萬芳高中    臺北市文山區興隆路三段115巷1號  0.0   0.0
# 79    再興中學        臺北市文山區興隆路四段2號  0.0   0.0
# 80    大誠高中      臺北市文山區秀明路二段175號  0.0   0.0
# 81    東山高中       臺北市文山區老泉街26巷3號  0.0   0.0
# 82    景文高中        臺北市文山區保儀路127號  0.0   0.0
# 83    滬江高中     臺北市文山區羅斯福路六段336號  0.0   0.0
# 84    文山特教      臺北市文山區秀明路一段169號  0.0   0.0
#
# [73 rows x 4 columns]

# %%
key1 = 'AIzaSyC-NUP-6jxk8jQIlAc4z0e-m2RDMnJsfM'
key2 = 'AIzaSyCKSOUbmMAcF_9RyZS-wFU74fPwJUHdN8o'
key3 = 'AIzaSyBvYksr15gUXBedtFlEBH1RQqL05kj4CRI'
key4 = 'AIzaSyCdST6Pb1KadM1F2r1MH4d_ySFPOKSIpYg'
key5 = 'AIzaSyBfGSH2Mn6kIVciwPvCkzU8qD6G6N5yCTM'
key6 = 'AIzaSyBBy5KU0Ea5uw4ly5aiCyyWTt7b97-JM6M'
key7 = 'AIzaSyCmzr4zXw0JifMK5_BNG3PKzYDox4ATF14'
key8 = 'AIzaSyAacwSxLi5_KbvwCQ4E76fIvKpP8kqbnx0'
key9 = 'AIzaSyCgULGix6zOYlVYbP64D1sIZwKpyiHyXJg'
key10 = 'AIzaSyAd0p4h1R7Vb-pnWF3DMdwHVxpAyyMHdKs'
key11 = 'AIzaSyDmb2Bm6RFFcd_7T5E1NuVewdlaF6dSNHo'
key12 = 'AIzaSyAhPBiGJ6-0CJUu-oVWNcLxlUjKcw6d8eg'
key13 = 'AIzaSyCykc0kco2cLUVrtJ5_qbnjWJ1C9PUHUwA'
key14 = 'AIzaSyCyVEdL6zR71c3Gl0w7QLvStgzEhvLMltk'
key15 = 'AIzaSyBkJgKPc83TYdUJDmOPPc-QergZqFUWvXc'
key16 = 'AIzaSyB1DhoIukRqpck7oCvejzY3v6GXbdInDe8'
key_list = [key1, key2, key3, key4, key5, key6, key7, key8, key9, key10, key11, key12, key13, key14, key15, key16]
key_num1 = 1

print("the current key number is " + str(key_num1+1))
i = 0
global keyStatus
keyStatus = 1
while i < len(highdf):
    addr = highdf.iloc[i][1]
    url = 'https://maps.googleapis.com/maps/api/geocode/xml?address=' + addr + '&key=' + key_list[int(key_num1)]
    r = requests.get(url)
    content = r.content
    bsobj = BeautifulSoup(content, 'html.parser')
    status = bsobj.find('status').get_text()
    if status == 'OVER_QUERY_LIMIT':
        print('need to change key, the current file number is ' + str(i))
        key_num1 = int(key_num1) + 1
        print('key number has changed to ' + str(key_num1))
        i+=1
        if key_num1 >= len(key_list):
            keyStatus = 0
            break
    elif status == 'OK':
        lat = bsobj.find_all('lat')[0].get_text()    
        long = bsobj.find_all('lng')[0].get_text()
        highdf['lat'][i] = lat
        highdf['long'][i] = long
        i+=1
    else:
        print('address is not vlaid, the current file number is ' + str(i))
        lat = 0
        long = 0
        highdf['lat'][i] = lat
        highdf['long'][i] = long
    print(i)
    print('緯度為: ' + str(lat))
    print('經度為: ' + str(long))
    time.sleep(1)        
return highdf
# Out:
# the current key number is 2
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 1
# 緯度為: 38.9780103
# 經度為: -94.6294669
# 2
# 緯度為: 25.0306892
# 經度為: 121.5128107
# 3
# 緯度為: 25.0385611
# 經度為: 121.5131031
# 4
# 緯度為: 25.0423335
# 經度為: 121.5236872
# 5
# 緯度為: 25.0156175
# 經度為: 121.5311921
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-0ab8721fb0c7> in <module>()
#      52     print('緯度為: ' + str(lat))
#      53     print('經度為: ' + str(long))
# ---> 54     time.sleep(1)
#      55 return highdf
#
# KeyboardInterrupt:

# %%
# jun_df.to_csv('C:/Users/Big data/Education/juniorhighsch.csv',index = False,encoding = 'utf-8-sig')

# %%
highdf
# Out:
#         校名                   地址        lat  long
# 1     建國中學         臺北市中正區南海路56號  25.038561   0.0
# 2     北一女中     臺北市中正區重慶南路一段165號  25.042334   0.0
# 3     成功高中       臺北市中正區濟南路一段71號  25.015618   0.0
# 4     南華高中       臺北市中正區汀州路三段58號  25.025016   0.0
# 5     強恕高中      臺北市中正區汀州路二段143號  25.042420   0.0
# 6     開南商工        臺北市中正區濟南路一段6號  25.060974   0.0
# 1     成淵高中      臺北市大同區承德路二段235號  25.038561   0.0
# 2     志仁高中     臺北市大同區南京西路64巷17號  25.042334   0.0
# 3     明倫高中      臺北市大同區承德路三段336號  25.015618   0.0
# 4     靜修女中         臺北市大同區寧夏路59號  25.025016   0.0
# 44    華岡藝校       臺北市士林區建業路73巷8號  25.052162   0.0
# 45    啟明學校    臺北市士林區忠誠路二段207巷1號  25.076246   0.0
# 46    中正高中        臺北市北投區文林北路77號  25.038561   0.0
# 47    薇閣高中         臺北市北投區珠海路50號  25.042334   0.0
# 48    復興高中        臺北市北投區復興四路70號  25.015618   0.0
# 49    十信高中       臺北市北投區北投路二段55號  25.025016   0.0
# 50    奎山實中        臺北市北投區明德路200號  25.042420   0.0
# 51    惇敘工商        臺北市北投區泉源路221號  25.060974   0.0
# 52    內湖高中        臺北市內湖區文德路218號  25.038561   0.0
# 53    麗山高中      臺北市內湖區環山路二段100號  25.042334   0.0
# 54    文德女中       臺北市內湖區成功路三段70號  25.015618   0.0
# 55    方濟高中       臺北市內湖區成功路三段61號  25.025016   0.0
# 56    達人女中      臺北市內湖區內湖路二段314號  25.042420   0.0
# 57    南湖高中      臺北市內湖區康寧路三段220號  25.060974   0.0
# 58    內湖高工      臺北市內湖區內湖路一段520號  25.052162   0.0
# 59    南港高中         臺北市南港區向陽路21號  25.038561   0.0
# 60    南港高工         臺北市南港區興中路29號  25.042334   0.0
# 61    育成高中        臺北市南港區重陽路366號  25.015618   0.0
# 62    景美女中      臺北市文山區木新路三段312號  25.038561   0.0
# 63    政大附中       臺北市文山區政大一街353號  25.042334   0.0
# 64    木柵高工       臺北市文山區木柵路四段77號  25.015618   0.0
# 65    萬芳高中    臺北市文山區興隆路三段115巷1號  25.025016   0.0
# 66    再興中學        臺北市文山區興隆路四段2號  25.042420   0.0
# 67    大誠高中      臺北市文山區秀明路二段175號  25.060974   0.0
# 68    東山高中       臺北市文山區老泉街26巷3號  25.052162   0.0
# 69    景文高中        臺北市文山區保儀路127號  25.076246   0.0
# 70    滬江高中     臺北市文山區羅斯福路六段336號  25.057931   0.0
# 71    文山特教      臺北市文山區秀明路一段169號  25.075351   0.0
#
# [72 rows x 4 columns]

# %%
if 'lat' not in jun_df.columns:
    jun_df['lat'] = pd.Series(np.zeros(len(jun_df)), index=jun_df.index)
    jun_df['long'] = pd.Series(np.zeros(len(jun_df)), index=jun_df.index)

# %%
key1 = 'AIzaSyC-NUP-6jxk8jQIlAc4z0e-m2RDMnJsfM'
key2 = 'AIzaSyCKSOUbmMAcF_9RyZS-wFU74fPwJUHdN8o'
key3 = 'AIzaSyBvYksr15gUXBedtFlEBH1RQqL05kj4CRI'
key4 = 'AIzaSyCdST6Pb1KadM1F2r1MH4d_ySFPOKSIpYg'
key5 = 'AIzaSyBfGSH2Mn6kIVciwPvCkzU8qD6G6N5yCTM'
key6 = 'AIzaSyBBy5KU0Ea5uw4ly5aiCyyWTt7b97-JM6M'
key7 = 'AIzaSyCmzr4zXw0JifMK5_BNG3PKzYDox4ATF14'
key8 = 'AIzaSyAacwSxLi5_KbvwCQ4E76fIvKpP8kqbnx0'
key9 = 'AIzaSyCgULGix6zOYlVYbP64D1sIZwKpyiHyXJg'
key10 = 'AIzaSyAd0p4h1R7Vb-pnWF3DMdwHVxpAyyMHdKs'
key11 = 'AIzaSyDmb2Bm6RFFcd_7T5E1NuVewdlaF6dSNHo'
key12 = 'AIzaSyAhPBiGJ6-0CJUu-oVWNcLxlUjKcw6d8eg'
key13 = 'AIzaSyCykc0kco2cLUVrtJ5_qbnjWJ1C9PUHUwA'
key14 = 'AIzaSyCyVEdL6zR71c3Gl0w7QLvStgzEhvLMltk'
key15 = 'AIzaSyBkJgKPc83TYdUJDmOPPc-QergZqFUWvXc'
key16 = 'AIzaSyB1DhoIukRqpck7oCvejzY3v6GXbdInDe8'
key_list = [key1, key2, key3, key4, key5, key6, key7, key8, key9, key10, key11, key12, key13, key14, key15, key16]

# %%
key_num1 = 1
i = 0
global keyStatus
keyStatus = 1
while i < len(jun_df):
    addr = jun_df.iloc[i][1]
    url = 'https://maps.googleapis.com/maps/api/geocode/xml?address=' + addr + '&key=' + key_list[int(key_num1)]
    r = requests.get(url)
    content = r.content
    bsobj = BeautifulSoup(content, 'html.parser')
    status = bsobj.find('status').get_text()
    if status == 'OVER_QUERY_LIMIT':
        print('need to change key, the current file number is ' + str(i))
        key_num1 = int(key_num1) + 1
        print('key number has changed to ' + str(key_num1))
        if key_num1 >= len(key_list):
            keyStatus = 0
            break
    elif status == 'OK':
        lat = bsobj.find_all('lat')[0].get_text()    
        long = bsobj.find_all('lng')[0].get_text()
        jun_df['lat'][i] = lat
        jun_df['long'][i] = long
        i+=1
    else:
        print('address is not vlaid, the current file number is ' + str(i))
        lat = 0
        long = 0
        jun_df['lat'][i] = lat
        jun_df['long'][i] = long
    if i % 500 == 0:
        print(i)
        print('緯度為: ' + str(lat))
        print('經度為: ' + str(long))
    time.sleep(1)
# Out:
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# c:\users\big data\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
jun_df.head()
# Out:
#          校名                地址        lat        long
# 0  市立北投國民中學      臺北市北投區溫泉路62號  25.134449  121.504201
# 1  市立明德國民中學      臺北市北投區明德路50號  25.107822  121.518445
# 2  市立石牌國民中學   臺北市北投區石牌路一段139號  25.114982  121.514173
# 3  市立新民國民中學      臺北市北投區新民路10號  25.138102  121.507636
# 4  市立關渡國民中學     臺北市北投區知行路212號  25.119885  121.467145

# %%
lat = jun_df['lat']
lat[1]
# Out:
# 25.1078221

# %%
def state_code():
    scale_km = 0.5
    lat = jun_df['lat']
    lon = jun_df['long']
    lat_to_km = lat*110.574
    lon_to_km = abs(lon*(111.320*cos(lat)))
    state_code_x = str(int(lat_to_km//scale_km))
    state_code_y = str(int(lon_to_km//scale_km))
    if len(state_code_y) == 4:
        state_code_y = '0'+state_code_y
    state_code = state_code_x+state_code_y
    return state_code

# %%
new_col = highdf.apply(state_code_compute,axis=1)
highdf['state_code'] = new_col

# %%
out_path = "C:/Users/Big data/Education/highsch.csv"
highdf.to_csv(out_path,index = False,encoding = 'utf-8-sig')
